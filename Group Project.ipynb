# %% [markdown]
# <a href="https://colab.research.google.com/github/Marcos-Almanzar/DiseasesofHeart/blob/master/Group%20Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.graphics.gofplots import qqplot 
import seaborn as sns
missing_values=["."]
dfcsv = df = pd.read_csv('https://raw.githubusercontent.com/Marcos-Almanzar/DiseasesofHeart/master/New_York_City_Leading_Causes_of_Death.csv',na_values = missing_values)
dfheart = df[(df['Leading Cause'] == 'Diseases of Heart (I00-I09, I11, I13, I20-I51)')]
dfheart = dfheart[['Leading Cause', 'Year', 'Sex', 'Deaths']]
sns.set(style="ticks")
g = sns.FacetGrid(dfheart, col="Sex", hue="Sex", height=6, aspect=1)
g.map(sns.barplot, "Year", "Deaths",ci=None)
plt.subplots_adjust(top=0.9, hspace = 0.9)
g.fig.suptitle('Heart Diseases')
g.add_legend();
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:723: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
sns.barplot(x = 'Year', y = 'Deaths', data =dfheart, hue='Sex', ci=None).set_title('Heart Diseases')
# Out:
# Text(0.5, 1.0, 'Heart Diseases')
